# %%
import cv2
import numpy as np
import time
import imutils
import math
from matplotlib import pyplot as plt

# %%
def show(img):
    plt.figure(figsize = (15,12))
    plt.imshow(img)
    plt.show()

# %%
image = "/home/office5/Desktop/TESTING/Anna2.bmp"
img = cv2.imread(image)
img.shape
# Out:
# (3136, 7296, 3)

# %%
show(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray,45,255,cv2.THRESH_BINARY)[1]

# %%
cnts, _ = cv2.findContours(thresh.copy(),
                        cv2.RETR_EXTERNAL,
                       cv2.CHAIN_APPROX_SIMPLE)
# cnts = cnts[0] if imutils.is_cv2() else cnts[1]

# %%
# show(cnts)import numpy as np
# import cv2

# im = cv2.imread('test.jpg')
# imgray = cv2.cvtColor(im,cv2.COLOR_BGR2GRAY)
# ret,thresh = cv2.threshold(imgray,127,255,0)
# contours, hierarchy = cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# cv2.drawContours(img, cnts, -1, (0,255,0), 3)
# cv2.imshow("title", img)
# cv2.waitKey(0)

# %%
# Setting All parameters
t_lower = 100  # Lower Threshold
t_upper = 200  # Upper threshold
aperture_size = 7  # Aperture size
L2Gradient = True
    
# Applying the Canny Edge filter
# with Custom Aperture Size
edge = cv2.Canny(img, t_lower, t_upper, L2gradient = L2Gradient)
show(edge)

# %%
print(len(edge),img.shape)
# Out:
# 3136 (3136, 7296, 3)

# %%
y, x, _ = img.shape
print(x,y)
# Out:
# 7296 3136

# %%
n = 8
start_x = 2
start_y = 7
# edge1 = edge[0:2000,3000:4000]
edge1 = edge[start_y * y // n: (start_y + 1) * y // n, start_x * x // n:(start_x + 1) * x // n]
show(edge1)

# %%
n = 8
start_x = 2
start_y = 7
# for i in range(0,x,200):
#     for j in range(0,y,400):
#         edge1 = edge[i:i+200,j:j+400]
#         print(i,i+200,j,j+400)
# edge1 = edge[0:50,0:100]
edge1 = edge[start_y * y // n: (start_y + 1) * y // n, start_x * x // n:(start_x + 1) * x // n]
show(edge1)

        # show(edge1)

# %%
cv2.imwrite("/home/office5/Desktop/TESTING/Anna2.bmp", edge1)
# Out:
# True

# %%
_, binaryImage=cv2.connectedComponents(edge1)

# %%
counts = len(np.unique(binaryImage))
counts
# Out:
# 157

# %%
math.ceil((912 / 912) * 8)
# Out:
# 8

# %%
# binaryImage[]

# %%
sorted_by_left = [[]] * 9
for i in range(counts):
    binaryImageClone = np.copy(binaryImage)
    binaryImageClone[binaryImageClone != i] = 0
#     sorted_by_left
    show(binaryImageClone)
